# %% [markdown]
# #**Actividad: Ajuste de redes neuronales**
# Alejandro Pizarro || Matrícula: A01633784 || Fecha: 08/09/2023

# %%
import pandas as pd
import numpy as np
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict
from sklearn.metrics import mean_squared_error, mean_absolute_error, classification_report

# %% [markdown]
# ##Ejercicio 1:

# %%
# Leemos nuestro conjunto de datos
df_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Aprendizaje/datasets/crime_data.csv')

# Eliminamos las columnas con las que no trabajaremos
columnas_a_eliminar = ['VR', 'S']
df_1 = df_1.drop(columnas_a_eliminar, axis=1)
df_1.head()
# Out:
#   State    MR     M     W     H     P
# 0    AK   9.0  41.8  75.2  86.6   9.1
# 1    AL  11.6  67.4  73.5  66.9  17.4
# 2    AR  10.2  44.7  82.9  66.3  20.0
# 3    AZ   8.6  84.7  88.6  78.7  15.4
# 4    CA  13.1  96.7  79.3  76.2  18.2

# %%
x = df_1[['M', 'W', 'H', 'P']].values # Variables predictoras
y = df_1['MR'].values # Variable de respuesta

# %% [markdown]
# ###1. Evalúa con validación cruzada un modelo pereceptrón multicapa para las variables que se te asignaron para este ejercicio.

# %%
features = x
n_features = len(x)

# Fit regression model using the complete dataset and calculate MSE and MAE
regr = MLPRegressor(hidden_layer_sizes=(20, 20), max_iter=20000)
regr.fit(x, y)

y_pred = regr.predict(x)
print('MSE: ', mean_squared_error(y, y_pred))
print("MAE: ", mean_absolute_error(y, y_pred))

# Evaluate regression model using k-fold cross-validation
n_folds = 5
kf = KFold(n_splits=n_folds, shuffle = True)

mse_cv = []
mae_cv = []
for train_index, test_index in kf.split(x):

    # Training phase
    x_train = x[train_index, :]
    y_train = y[train_index]

    regr_cv = MLPRegressor(hidden_layer_sizes=(20, 20), max_iter=20000)
    regr_cv.fit(x_train, y_train)

    # Test phase
    x_test = x[test_index, :]
    y_test = y[test_index]

    y_pred = regr_cv.predict(x_test)

    # Calculate MSE and MAE

    mse_i = mean_squared_error(y_test, y_pred)
    print('mse = ', mse_i)
    mse_cv.append(mse_i)

    mae_i = mean_absolute_error(y_test, y_pred)
    print('mae = ', mae_i)
    mae_cv.append(mae_i)


print('MSE:', np.average(mse_cv), '  MAE:', np.average(mae_cv))
# Out:
# MSE:  150.6702173080058
# MAE:  8.670540993551283
# mse =  3.9541515259826636
# mae =  1.532457115799293
# mse =  1.2147391721990555
# mae =  0.8205371375184562
# mse =  5.311742357816818
# mae =  1.8676788774393611
# mse =  23.908138485363665
# mae =  3.4592419033144957
# mse =  282.77473686602724
# mae =  8.329168875501214
# MSE: 63.43270168147789   MAE: 3.2018167819145638

# %% [markdown]
# ###2. Agrega al conjunto de datos columnas que representen los cuadrados de las variables predictoras (por ejemplo, M2, W2), así como los productos entre pares de variables (por ejemplo, PxS, MxW). Evalúa un modelo perceptrón multicapa para este nuevo conjunto de datos.

# %%
df_1['M2'] = df_1['M'] ** 2
df_1['W2'] = df_1['W'] ** 2
df_1['H2'] = df_1['H'] ** 2
df_1['P2'] = df_1['P'] ** 2

df_1['MxW'] = df_1['M'] * df_1['W']
df_1['MxH'] = df_1['M'] * df_1['H']
df_1['MxP'] = df_1['M'] * df_1['P']

df_1['WxH'] = df_1['W'] * df_1['H']
df_1['WxP'] = df_1['W'] * df_1['P']

df_1['HxP'] = df_1['H'] * df_1['P']

x = df_1[['M', 'W', 'H', 'P','M2', 'W2', 'H2', 'P2', 'MxW', 'MxH', 'MxP', 'WxH', 'WxP', 'HxP']].values
y = df_1['MR'].values

# %%
features = x
n_features = len(x)

# Fit regression model using the complete dataset and calculate MSE and MAE
regr = MLPRegressor(hidden_layer_sizes=(20, 20), max_iter=20000)
regr.fit(x, y)

y_pred = regr.predict(x)
print('MSE: ', mean_squared_error(y, y_pred))
print("MAE: ", mean_absolute_error(y, y_pred))

# Evaluate regression model using k-fold cross-validation
n_folds = 5
kf = KFold(n_splits=n_folds, shuffle = True)

mse_cv = []
mae_cv = []
for train_index, test_index in kf.split(x):

    # Training phase
    x_train = x[train_index, :]
    y_train = y[train_index]

    regr_cv = MLPRegressor(hidden_layer_sizes=(20, 20), max_iter=20000)
    regr_cv.fit(x_train, y_train)

    # Test phase
    x_test = x[test_index, :]
    y_test = y[test_index]

    y_pred = regr_cv.predict(x_test)

    # Calculate MSE and MAE

    mse_i = mean_squared_error(y_test, y_pred)
    print('mse = ', mse_i)
    mse_cv.append(mse_i)

    mae_i = mean_absolute_error(y_test, y_pred)
    print('mae = ', mae_i)
    mae_cv.append(mae_i)


print('MSE:', np.average(mse_cv), '  MAE:', np.average(mae_cv))
# Out:
# MSE:  109918.3773773718
# MAE:  293.7970316327061
# mse =  74129.88860202458
# mae =  215.13291305271895
# mse =  99.43373051928594
# mae =  6.629441967100712
# mse =  469587.54077917646
# mae =  546.5139619095933
# mse =  109.6023623487529
# mae =  7.165702976318094
# mse =  1937.4816701415082
# mae =  32.884079036106826
# MSE: 109172.7894288421   MAE: 161.66521978836758

# %% [markdown]
# ###3. Viendo los resultados de regresión, desarrolla una conclusión sobre los siguientes puntos:

# %% [markdown]
# A. ¿Consideras que el modelo perceptrón multicapa es efectivo para modelar los datos del problema? ¿Por qué?
#
# * En este caso, se observa que el modelo sin la inclusión de los cuadrados de las variables predictoras arroja un mejor ajuste (MSE: 155.08, MAE: 4.38) en comparación con el modelo que los incluye (MSE: 68807.24, MAE: 119.31). Sin embargo, es importante destacar que ambos modelos presentan errores considerables, lo que sugiere que ninguno de ellos evalúa efectivamente la idoneidad del modelo para representar la complejidad de los datos.
#
# B. ¿Qué modelo es mejor para los datos de criminalidad, el lineal o el perceptrón multicapa? ¿Por qué?
#
# * En base a las métricas de rendimiento, el modelo de regresión lineal es preferible sobre el perceptrón multicapa para los datos de criminalidad, ya que tiene un MSE y un MAE significativamente más bajos, lo que indica una mejor capacidad para predecir los valores reales.

# %% [markdown]
# ##Ejercicio 2:

# %%
data_2 = np.loadtxt('/content/drive/MyDrive/Colab Notebooks/Aprendizaje/datasets/M_5.txt')

# Variables regresoras y variable dependiente
x = data_2[:,2:]
y = data_2[:,0]

# %% [markdown]
# ###1. Evalúa un modelo perceptrón multicapa con validación cruzada utilizando al menos 5 capas de 20 neuronas.

# %%
# %%time
features = x
n_features = len(x)

################################################################################
# Train model with all observations (two layers of 100 neurons)
################################################################################
clf = MLPClassifier(hidden_layer_sizes=(20, 20, 20, 20, 20), max_iter=10000)
clf.fit(x, y)

################################################################################
# Evaluate model (two layers of 100 neurons)
################################################################################
y_pred = cross_val_predict(MLPClassifier(hidden_layer_sizes=(20, 20, 20, 20, 20), max_iter=10000), x, y)
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.93      0.93        90
#          2.0       0.66      0.68      0.67        90
#          3.0       0.97      0.96      0.96        90
#          4.0       0.98      0.91      0.94        90
#          5.0       0.95      0.98      0.96        90
#          6.0       0.69      0.68      0.69        90
#          7.0       0.96      0.99      0.97        89
#
#     accuracy                           0.87       629
#    macro avg       0.87      0.87      0.87       629
# weighted avg       0.87      0.87      0.87       629
#
# CPU times: user 13.2 s, sys: 7.5 s, total: 20.7 s
# Wall time: 13.1 s

# %% [markdown]
# ###2. Evalúa un modelo perceptrón multicapa con validación cruzada, pero encontrando el número óptimo de capas y neuronas de la red.

# %%
# %%time
################################################################################
# Optimal number of layers and neurons
################################################################################

num_layers = np.arange(1, 20, 5)
num_neurons = np.arange(10, 110, 20)

layers = []

for l in num_layers:
    for n in num_neurons:
        layers.append(l*[n])

clf = GridSearchCV(MLPClassifier(max_iter=10000), {'hidden_layer_sizes': layers}, cv = 5)
clf.fit(x, y)
print(clf.best_estimator_)
# Out:
# MLPClassifier(hidden_layer_sizes=[90], max_iter=10000)
# CPU times: user 5min 6s, sys: 2min 22s, total: 7min 29s
# Wall time: 4min 36s

# %% [markdown]
# ###3. Prepara el modelo perceptrón multicapa:
# A. Opten los hiperparámetros óptimos de capas y neuronas de la red.
#
# B. Con los hiperparámetros óptimos, ajusta el modelo con todos los datos.

# %%
# %%time
################################################################################
# Evaluate model finding the optimal number of layers and neurons
################################################################################

clf = GridSearchCV(MLPClassifier(max_iter=10000), {'hidden_layer_sizes': layers}, cv = 5)
y_pred = cross_val_predict(clf, x, y, cv = 5)
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.91      0.93        90
#          2.0       0.69      0.74      0.72        90
#          3.0       0.98      0.98      0.98        90
#          4.0       0.98      0.96      0.97        90
#          5.0       0.91      0.94      0.93        90
#          6.0       0.76      0.70      0.73        90
#          7.0       0.97      0.99      0.98        89
#
#     accuracy                           0.89       629
#    macro avg       0.89      0.89      0.89       629
# weighted avg       0.89      0.89      0.89       629
#
# CPU times: user 15min 53s, sys: 7min 46s, total: 23min 39s
# Wall time: 14min 39s

# %% [markdown]
# ###4. Contesta lo siguientes:

# %% [markdown]
# A. ¿Observas alguna mejora importante al optimizar el tamaño de la red? ¿Es el resultado que esperabas? Argumenta tu respuesta.
#
# * El modelo inicial demostró un rendimiento sólido, alcanzando una precisión del 87%. Sin embargo, al implementar capas adicionales de redes neuronales, logramos mejorar el rendimiento promedio del modelo hasta alcanzar un 89%. Esto representa una mejora general de 0.02 puntos porcentuales en la precisión del modelo lo cual es un resultado menor al esperado.
#
# B. ¿Qué inconvenientes hay al encontrar el tamaño óptimo de la red? ¿Por qué?
#
# * El principal desafío que se enfrentó es el factor tiempo y nuestra capacidad computacional limitada. Implementar capas adicionales puede requerir el doble o más de tiempo en comparación con la configuración actual. Esta inversión de tiempo es significativa, y se traduce en mejoras mínimas, alrededor del 0.02%. Por lo tanto, ss esencial realizar un análisis cuidadoso para determinar si la implementación de estas capas adicionales es la opción más óptima. A pesar del incremento en el tiempo necesario, los resultados no muestran  una mejora evidente en nuestros objetivos.

# %%
# !apt-get install -y texlive-xetex
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
# !jupyter nbconvert --to pdf '/content/drive/MyDrive/Colab Notebooks/Aprendizaje/redes_neuronalesA01633784.ipynb' --output-dir='/content/drive/MyDrive/Colab Notebooks/Aprendizaje'
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/Aprendizaje/redes_neuronalesA01633784.ipynb to pdf
# [NbConvertApp] Writing 60471 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 62624 bytes to /content/drive/MyDrive/Colab Notebooks/Aprendizaje/redes_neuronalesA01633784.pdf
