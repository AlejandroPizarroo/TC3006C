# %%
import pandas as pd
import numpy as np
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Estadística/Actividades en clase/datasets/historial_clientes.xlsx')

# %%
df.head()
# Out:
#    Cliente A  Cliente B
# 0   1.247098   2.095465
# 1   0.936653   1.484473
# 2  -0.186285   1.744021
# 3   1.494336   1.683304
# 4   2.557917   2.306799

# %% [markdown]
# **Prueba Z**
# Hipótesis nula
# $H_0:\mu_1=\mu2$
#
# Estadistico de prueba
#
# $Z=\frac{\overline{x}-\overline{y}-(\mu_1\mu_2))}{\sqrt{\fracc{\sigma_1^2}{m}+\frac{\sigma_2^2}{n}}}$
#
# El estadistico de prueba tiene una distribución normal estándar

# %%
df.describe()
# Out:
#          Cliente A    Cliente B
# count  1101.000000  1101.000000
# mean      2.006974     2.123149
# std       1.025550     1.017484
# min      -1.752928    -0.778317
# 25%       1.357532     1.403232
# 50%       1.996068     2.141925
# 75%       2.706549     2.756875
# max       5.556386     5.096496

# %%
# Realizar el ztest
from statsmodels.stats.weightstats import ztest

ztest(df['Cliente A'], df['Cliente B'])
# Out:
# (-2.6683380460572605, 0.007622751887296756)

# %% [markdown]
# Dado que $-2.66\notin[-1.96, 1.96]$ Se rechaza $H0$

# %% [markdown]
# #Prueba T
# ##Distribución t-student

# %%
import pingouin as pg
# Descarga de datos
# ==============================================================================
url = ('https://raw.githubusercontent.com/JoaquinAmatRodrigo/' +
       'Estadistica-machine-learning-python/master/data/births.csv')
datos = pd.read_csv(url, sep=',')
datos.head()
# Out:
#    f_age  m_age  weeks  premature  visits  gained  weight sex_baby      smoke
# 0   31.0     30     39  full term    13.0     1.0    6.88     male     smoker
# 1   34.0     36     39  full term     5.0    35.0    7.69     male  nonsmoker
# 2   36.0     35     40  full term    12.0    29.0    8.88     male  nonsmoker
# 3   41.0     40     40  full term    13.0    30.0    9.00   female  nonsmoker
# 4   42.0     37     40  full term     NaN    10.0    7.94     male  nonsmoker

# %% [markdown]
# **Prueba T--student**
# Hipótesis nula
# $H_0:\mu_1=\mu2$
#
# Estadistico de prueba
#
# $T=\frac{\overline{x}-\overline{y}-(\mu_1\mu_2)}{\sqrt{\fracc{\sigma_1^2}{m}+\frac{\sigma_2^2}{n}}}$
#
# El estadistico de prueba tiene una distribución t-student

# %%
# Filtrar la base de datos en madres fumadoras y no fumadoras
peso_smokers = datos.loc[datos.smoke=='smoker', 'weight']
peso_nonsmokers = datos.loc[datos.smoke=='nonsmoker', 'weight']

# %%
# Aplicando el t-test
pg.ttest(x=peso_smokers, y=peso_nonsmokers)
# Out:
#                T        dof alternative     p-val          CI95%   cohen-d  \
# T-test -1.496711  89.277413   two-sided  0.137995  [-0.93, 0.13]  0.268758
#
#          BF10     power
# T-test  0.512  0.338075
