# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# Lectura de base de datos
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estadística/Actividades en clase/datasets/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #Anova unifactorial
# El ANOVA se utiliza para comparar más de dos medias poblacionales
#
# $H_0: \mu_1\mu_2=\cdots=\mu_I$
#
# contra $H_a:$ al menos alguna $\mu_i$ es diferente.
# El estadístico de prueba tiene distribución F

# %%
# ANOVA usando el factor sepalo
longitud_especie = ols('SepalLengthCm~C(Species)', data=df).fit()
sm.stats.anova_lm (longitud_especie, type=2)
# Out:
#                df     sum_sq    mean_sq           F        PR(>F)
# C(Species)    2.0  63.212133  31.606067  119.264502  1.669669e-31
# Residual    147.0  38.956200   0.265008         NaN           NaN

# %%
modelo = ols(formula = 'SepalLengthCm~C(Species)', data=df)
modelo.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          SepalLengthCm   R-squared:                       0.619
# Model:                            OLS   Adj. R-squared:                  0.614
# Method:                 Least Squares   F-statistic:                     119.3
# Date:                Mon, 28 Aug 2023   Prob (F-statistic):           1.67e-31
# Time:                        22:47:43   Log-Likelihood:                -111.73
# No. Observations:                 150   AIC:                             229.5
# Df Residuals:                     147   BIC:                             238.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #Utilizar test Tuket (Método T) para saber cuál especie es diferente

# %%
import statsmodels.stats.multicomp as multi
multi_comp = multi.MultiComparison(df['SepalLengthCm'], df['Species'])
multi_comp.tukeyhsd().summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
